# %% [markdown]
# # UNITREE G1 · GR00T 全身控制（WBC + finetune 路线）
#
# **目标**：用 NVIDIA 的 **GEAR-SONIC 全身控制器（WBC）当平衡底座**，再 finetune GR00T 让 G1 跳舞 —— 平衡交给鲁棒 WBC，VLA 只出高层 latent，**from construction 不摔**（对比我们 raw-joint ACT 蒸馏 0.5s 必摔）。
#
# ## 为什么走这条路
# - 我们的 ACT 学生直接出 29-DoF 关节角 → covariate shift → 闭环 0.5s 摔。
# - `UNITREE_G1_SONIC` 路线：VLA → SONIC **latent** → GEAR-SONIC WBC 解码 → 稳定全身关节。WBC 已会走/跑/跳，VLA 不用学精细平衡。
#
# ## 关键事实（已核实）
# - `UNITREE_G1` / `UNITREE_G1_SONIC` 是 GR00T 的**动作空间配置（embodiment tag）**，不是现成模型；是 **posttrain tag**，要 finetune 才有 checkpoint。
# - **没有现成微调好的 G1 VLA checkpoint**（GR00T-WholeBodyControl 的 VLA workflow 明确要从 `nvidia/GR00T-N1.7-3B` base 自己 finetune）→ 所以我们 **WBC + finetune**。
# - 真正可下载的就两个：
#   | 模型 | 是什么 | 能否预览 G1 |
#   |---|---|---|
#   | `nvidia/GEAR-SONIC` | WBC 底座（walk/run/jump），encoder/decoder/planner ONNX | ✅ 能（键盘交互 MuJoCo viewer） |
#   | `nvidia/GR00T-N1.7-3B` | VLA「大脑」base | ❌ 单独不能（要 +WBC +finetune） |
#
# 调研详见 `doc/vla_data_expansion_covariate_shift.html` §6（架构侧 SONIC WBC 路线）。

# %% [markdown]
# ## ① GEAR-SONIC WBC — 下载 + 安装（一次性，较重）
#
# clone `NVlabs/GR00T-WholeBodyControl` → 装 MuJoCo sim 依赖（需 TensorRT + C++ build）→ 下载 GEAR-SONIC checkpoints。
# 首次较慢；若 install 报错按 repo README 处理 TensorRT。

# %%
# !bash scripts/gear_sonic_setup.sh

# %% [markdown]
# ## ① 实时预览 GEAR-SONIC 行为（Isaac Lab eval，会走/踢/舞的 base）
#
# 单进程 Isaac Sim viewer 跑已发布的 SONIC WBC（`sonic_release/last.pt`），让它实时**跟踪**参考动作 —— **无 DDS、无 C++**。下面 cell 先看一条 walk，快速确认环境通。
#
# **viewer 快捷键**（先点一下视口让它获得焦点）：
# - `F` 自由相机（**停止自动跟随**，可自由拉远/旋转看全场）
# - `R` 重置所有 env（动作重头播） · `T` 下一批 motion · `V` 参考骨架（绿点=目标姿态，看跟踪误差）。

# %%
# !bash scripts/gear_sonic_preview.sh

# %% [markdown]
# ## ③ 一键看 SONIC 各动作（架构侧 Milestone 0 go/no-go）
#
# 本地 deploy demo 动作转成 `robot_filtered` 后，让 SONIC WBC 实时**跟踪**。**跟得住不摔 = 该动作活在 SONIC 的 token 空间**，后面 VLA 只要吐对应 64 维 token 就能驱动它（详见 `doc/groot_sonic_wbc_route.html`）。
#
# 每个 cell = 一个 G1 跑一条动作。重点看 **kick / dance / macarena** 摔不摔、跟不跟得上参考。
# > 首次运行任意一条会自动建 `data/demo_robot_filtered.pkl`（7 条一起转，之后秒起）。关闭 viewer 窗口或 `Ctrl+C` 结束。
#
# ### viewer 快捷键（先点一下视口让它获得焦点）
# | 键 | 作用 |
# |---|---|
# | **`F`** | **自由相机** —— 停止自动跟随机器人，可自由拉远/旋转/缩放看全场（解决"拉近就被复位"） |
# | `R` | 重置所有 env，动作从头播 |
# | `T` | 切换下一批 motion |
# | `V` | 开关参考骨架可视化（绿点 = 目标姿态，肉眼看跟踪误差） |
#
# > 默认是"相机跟随 env 0"模式，所以你拖拽视角下一帧会被拽回 —— **按 `F` 即可解除**。

# %%
# 🕺 跳舞 dance_in_da_party
# !bash scripts/gear_sonic_demo.sh dance

# %%
# 🕺 macarena
# !bash scripts/gear_sonic_demo.sh macarena

# %%
# 🥋 踢腿 neutral_kick
# !bash scripts/gear_sonic_demo.sh kick

# %%
# 🦵 弓步 forward_lunge
# !bash scripts/gear_sonic_demo.sh lunge

# %%
# 🦘 单腿跳 one_leg_jumping
# !bash scripts/gear_sonic_demo.sh jump

# %%
# 🏋️ 深蹲 squat
# !bash scripts/gear_sonic_demo.sh squat

# %%
# 🚶 转身走 walking_quip_360
# !bash scripts/gear_sonic_demo.sh walk

# %% [markdown]
# ### 全部 7 条一排（每个 G1 各跳一条，paired 排开）

# %%
# 7 个 G1 一排，各跳一条
# !bash scripts/gear_sonic_demo.sh

# %% [markdown]
# ## ② GR00T-N1.7-3B base VLA — 下载（finetune 用）
#
# 下载 VLA「大脑」base。**单独不能驱动 G1**（要配 SONIC WBC + finetune）。
# gated：可能需 `huggingface-cli login` + 申请 access。

# %%
# !bash scripts/groot_n17_download.sh

# %% [markdown]
# ## ④ 架构侧 VLA 自训 pipeline（record → finetune → 部署，全一键）
#
# **思路**：GR00T N1.7 只输出 SONIC 的 64 维 FSQ token，WBC 当平衡底座解码成关节。
# 数据来自 SONIC 自己跟踪本地动作时录下的真 token（无需 VR），prompt 作为条件。
#
# **链路**：`record(裸token npz)` → `convert(LeRobot v2.1)` → `finetune GR00T` → `open-loop eval(MSE)` → `dump 预测token` → `注入 SONIC 看动作`。
#
# > 实测：8000 步后 open-loop token MSE **0.0011**（比 predict-mean 基线低 ~35×），踢腿/舞步注入后与 GT 基本同步 → 架构侧 GO（训练集内）。
# > ⚠️ 现为 7-ep **过拟合**演示；**实时下任意 prompt + 泛化(held-out)= 下一步**。各 cell 较重（数据/GPU），按需跑。

# %% [markdown]
# ### 4.1 录制 token 数据集（SONIC 跟踪 7 条动作，抽真 token+相机+proprio → 裸 npz）

# %%
# headless 逐条录制，每条 1 episode（EPISODES=N 增量、SMOKE=1 快验）
# !bash scripts/gear_sonic_record.sh

# %% [markdown]
# ### 4.2 转 UNITREE_G1_SONIC LeRobot v2.1（官方 Gr00tDataExporter，需 .venv_data_collection）

# %%
# !cd dependencies/GR00T-WholeBodyControl && .venv_data_collection/bin/python \
  ../../scripts/sonic_vla_npz_to_lerobot.py \
  --raw-dir ../../datasets/sonic_vla_raw --out ../../datasets/sonic_vla_lerobot

# %% [markdown]
# ### 4.3 finetune GR00T N1.7-3B（单 4090，冻结 VLM 训 DiT 头，adafactor+grad-ckpt，崩了自愈续训）

# %%
# 全新 8000 步（让 LR schedule 铺满）；崩溃/重启自愈见 /tmp/resume_8k_heal.sh
# !MAX_STEPS=8000 SAVE_STEPS=500 OUT_DIR=$PWD/outputs/gr00t_sonic_8k bash scripts/gr00t_sonic_finetune.sh

# %% [markdown]
# ### 4.4 open-loop eval（预测 vs GT token 的 MSE，判 go/no-go；基线 per-motion-mean≈0.039）

# %%
# !cd dependencies/Isaac-GR00T && COMPILE_ACTION_HEAD_DISABLE=1 PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True \
  .venv/bin/python gr00t/eval/open_loop_eval.py \
  --model_path ../../outputs/gr00t_sonic_8k/checkpoint-8000 \
  --dataset_path ../../datasets/sonic_vla_lerobot \
  --embodiment_tag unitree_g1_sonic --action_horizon 40 --traj_ids 0 1 2 3 4 5 6 --steps 150

# %% [markdown]
# ### 4.5 dump 预测 token（GR00T 对每条动作 open-loop 出 64 维 token → npz，供注入）

# %%
# !cd dependencies/Isaac-GR00T && COMPILE_ACTION_HEAD_DISABLE=1 \
  .venv/bin/python ../../scripts/gr00t_dump_pred_tokens.py \
  --model_path ../../outputs/gr00t_sonic_8k/checkpoint-8000 \
  --dataset_path ../../datasets/sonic_vla_lerobot --out ../../datasets/sonic_vla_pred_8k_final

# %% [markdown]
# ### 4.6 注入 SONIC 看 GR00T 驱动的动作（默认用 checkpoint-8000 token + 放宽终止）
# prompt→GR00T→token→SONIC 解码→G1 动，全内存无 C++。viewer：F 自由相机、V 参考、R 重置。

# %%
# 🕺 dance — GR00T 预测 token 驱动
# !bash scripts/gear_sonic_inject.sh dance

# %%
# 🕺 macarena（最长 27.5s）
# !bash scripts/gear_sonic_inject.sh macarena

# %%
# 🥋 kick 踢腿
# !bash scripts/gear_sonic_inject.sh kick

# %%
# 🦵 lunge 弓步
# !bash scripts/gear_sonic_inject.sh lunge

# %%
# 🦘 jump 单腿跳
# !bash scripts/gear_sonic_inject.sh jump

# %%
# 🏋️ squat 深蹲
# !bash scripts/gear_sonic_inject.sh squat
# Out:
# [inject] motion=squat key=squat_001__A359  GR00T tokens=/home/david/work/isaaclab-experience/datasets/sonic_vla_pred_8k_final/squat_001__A359.npz
#   Isaac viewer: press F=free cam, V=show green ref-skeleton (target) vs robot (GR00T-driven).
#   Isaac viewer: F=free cam, V=ref skeleton, R=reset.  RELAX=1 (1=play full motion, no deviation-reset).
# 2026-06-04 09:10:59.396 | WARNING  | gear_sonic.utils.config_utils:register_rl_resolvers:20 - Warning: Some resolvers already registered: resolver 'eval' is already registered
# /home/david/work/isaaclab-experience/dependencies/GR00T-WholeBodyControl/gear_sonic/eval_agent_trl.py:61: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="config", config_name="base_eval")
# /home/david/miniconda3/envs/isaaclab/lib/python3.11/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# 2026-06-04 09:10:59.492 | INFO     | __main__:main:90 - Loading training config file from sonic_release/config.yaml
# Setting seed: 0
# [WARN][AppLauncher]: There are no arguments attached to the ArgumentParser object. If you have your own arguments, please load your own arguments before calling the `AppLauncher.add_app_launcher_args` method. This allows the method to check the validity of the arguments and perform checks for argument names.
# [INFO][AppLauncher]: Using device: cuda
# [INFO][AppLauncher]: Loading experience file: /home/david/work/isaaclab-experience/IsaacLab/apps/isaaclab.python.kit
# Loading user config located at: '/home/david/miniconda3/envs/isaaclab/lib/python3.11/site-packages/isaacsim/kit/data/Kit/Isaac-Sim/5.1/user.config.json'
# [0.038s] [ext: omni.kit.async_engine-0.0.3] startup
# [2026-06-04 09:10:59,931][asyncio][DEBUG] - Using selector: EpollSelector
# [0.131s] [ext: omni.metrics.core-0.0.3] startup
# [0.131s] [ext: omni.client.lib-1.1.0] startup
# [0.139s] [ext: omni.blobkey-1.1.2] startup
# [0.139s] [ext: omni.stats-1.0.1] startup
# [0.139s] [ext: omni.datastore-0.0.0] startup
# [0.143s] [ext: omni.client-1.3.0] startup
# [0.145s] [ext: omni.ujitso.default-1.0.0] startup
# [0.146s] [ext: omni.hsscclient-1.1.2] startup
# [0.148s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.149s] [ext: omni.assets.plugins-0.0.0] startup
# [0.150s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.154s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.158s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 580.126.09    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24564   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | 308302d3.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 24.04.2 LTS (Noble Numbat) ubuntu, Version: 24.04.2, Kernel: 6.17.0-22-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101011 (1.21.1.11)
# | Processor: 13th Gen Intel(R) Core(TM) i9-13900KF
# | Cores: 24 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64131 | Free Memory: 53950
# | Total Page/Swap (MB): 8191 | Free Page/Swap: 8189
# |---------------------------------------------------------------------------------------------|
# [0.716s] [ext: omni.materialx.libs-1.0.7] startup
# [0.721s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.721s] [ext: omni.usd.config-1.0.6] startup
# [0.723s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.723s] [ext: omni.usd.libs-1.0.1] startup
# [0.780s] [ext: omni.mdl-56.0.3] startup
# [0.794s] [ext: omni.iray.libs-0.0.0] startup
# [0.797s] [ext: omni.mdl.neuraylib-0.2.12] startup
# [0.798s] [ext: omni.kit.usd.mdl-1.1.5] startup
# [0.851s] [ext: omni.kit.loop-isaac-1.3.7] startup
# [0.852s] [ext: omni.kit.test-2.0.1] startup
# [0.870s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.870s] [ext: omni.kit.telemetry-0.5.2] startup
# [0.893s] [ext: omni.appwindow-1.1.10] startup
# [1.316s] [ext: omni.kit.renderer.core-1.1.0] startup
# [8.304s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [8.305s] [ext: omni.kit.renderer.imgui-2.0.5] startup
# [8.339s] [ext: omni.ui-2.27.1] startup
# [8.345s] [ext: omni.kit.mainwindow-1.0.3] startup
# [8.346s] [ext: carb.audio-0.1.0] startup
# [8.348s] [ext: omni.uiaudio-1.0.0] startup
# [8.348s] [ext: omni.kit.uiapp-0.0.0] startup
# [8.348s] [ext: omni.usd.schema.metrics.assembler-107.3.1] startup
# [8.350s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [8.353s] [ext: omni.usd.schema.audio-0.0.0] startup
# [8.356s] [ext: omni.pip.cloud-1.4.3] startup
# [8.357s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [8.359s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [8.360s] [ext: omni.usd.schema.anim-0.0.0] startup
# [8.373s] [ext: usdrt.scenegraph-7.6.1] startup
# [8.395s] [ext: omni.activity.core-1.0.3] startup
# [8.396s] [ext: omni.kit.actions.core-1.0.0] startup
# [8.397s] [ext: omni.usd_resolver-1.0.0] startup
# [8.400s] [ext: omni.kit.commands-1.4.10] startup
# [8.402s] [ext: omni.usd.core-1.5.3] startup
# [8.403s] [ext: omni.resourcemonitor-107.0.1] startup
# [8.404s] [ext: omni.kit.audiodeviceenum-1.0.2] startup
# [8.405s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [8.409s] [ext: omni.kit.usd_undo-0.1.8] startup
# [8.410s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [8.412s] [ext: omni.graph.exec-0.9.6] startup
# [8.412s] [ext: omni.timeline-1.0.14] startup
# [8.413s] [ext: omni.kit.widget.nucleus_connector-2.0.1] startup
# [8.414s] [ext: omni.kit.exec.core-0.13.4] startup
# [8.415s] [ext: omni.hydra.scene_delegate-0.3.4] startup
# [8.418s] [ext: omni.usd-1.13.10] startup
# [8.447s] [ext: omni.kit.asset_converter-5.0.17] startup
# [8.453s] [ext: omni.usd.schema.omni_lens_distortion-0.0.0] startup
# [8.454s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [8.457s] [ext: isaacsim.robot.schema-3.6.0] startup
# [8.462s] [ext: omni.usd.schema.render_settings.rtx-0.0.0] startup
# [8.462s] [ext: omni.usd.schema.physx-107.3.26] startup
# [8.481s] [ext: omni.usd.schema.omni_sensors-0.0.0] startup
# [8.482s] [ext: omni.index.libs-380600.8087.0] startup
# [8.482s] [ext: omni.volume-0.5.2] startup
# [8.483s] [ext: omni.ujitso.client-0.0.0] startup
# [8.483s] [ext: omni.index-1.0.1] startup
# [8.484s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [8.484s] [ext: omni.hydra.rtx-1.0.0] startup
# [8.505s] [ext: omni.kit.notification_manager-1.0.10] startup
# [8.506s] [ext: omni.kit.clipboard-1.0.5] startup
# [8.507s] [ext: omni.kit.viewport.legacy_gizmos-1.0.19] startup
# [8.508s] [ext: omni.kit.raycast.query-1.1.0] startup
# [8.512s] [ext: omni.kit.menu.core-1.1.2] startup
# [8.512s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [8.514s] [ext: omni.kit.helper.file_utils-0.1.9] startup
# [8.515s] [ext: omni.kit.widget.path_field-2.0.11] startup
# [8.515s] [ext: omni.kit.widget.context_menu-1.2.5] startup
# [8.516s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [8.516s] [ext: omni.kit.widget.filebrowser-2.12.3] startup
# [8.518s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [8.518s] [ext: omni.kit.usd.layers-2.2.11] startup
# [8.523s] [ext: omni.ui.scene-1.11.5] startup
# [8.525s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [8.526s] [ext: omni.kit.window.filepicker-2.13.4] startup
# [8.531s] [ext: omni.kit.menu.utils-2.0.5] startup
# [8.535s] [ext: omni.kit.context_menu-1.8.6] startup
# [8.536s] [ext: omni.kit.viewport.scene_camera_model-1.0.6] startup
# [8.539s] [ext: omni.kit.hydra_texture-1.4.6] startup
# [8.541s] [ext: omni.kit.window.file_importer-1.1.18] startup
# [8.542s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [8.543s] [ext: omni.kit.window.drop_support-1.0.5] startup
# [8.543s] [ext: omni.kit.widget.viewport-107.1.3] startup
# [8.545s] [ext: omni.kit.material.library-2.0.7] startup
# [8.548s] [ext: omni.hydra.engine.stats-1.0.3] startup
# [8.549s] [ext: omni.kit.widget.settings-1.2.6] startup
# [8.551s] [ext: omni.kit.viewport.window-107.2.0] startup
# [8.558s] [ext: omni.kit.window.preferences-1.8.0] startup
# [8.561s] [ext: omni.kit.widget.toolbar-2.0.1] startup
# [8.563s] [ext: omni.kit.viewport.utility-1.1.2] startup
# [8.564s] [ext: omni.kit.manipulator.transform-107.0.0] startup
# [8.566s] [ext: omni.kit.manipulator.tool.snap-1.5.13] startup
# [8.568s] [ext: omni.kit.manipulator.selector-1.1.3] startup
# [8.569s] [ext: omni.kit.property.adapter.core-1.0.2] startup
# [8.570s] [ext: omni.kit.viewport.manipulator.transform-107.0.4] startup
# [8.571s] [ext: omni.kit.manipulator.viewport-107.0.1] startup
# [8.571s] [ext: omni.kit.property.adapter.fabric-1.0.3] startup
# [8.572s] [ext: omni.kit.manipulator.prim.core-107.0.8] startup
# [8.575s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [8.577s] [ext: omni.kit.widget.filter-1.1.4] startup
# [8.577s] [ext: omni.kit.hotkeys.core-1.3.10] startup
# [8.578s] [ext: omni.kit.manipulator.prim.usd-107.0.3] startup
# [8.578s] [ext: omni.fabric.commands-1.1.6] startup
# [8.580s] [ext: omni.kit.window.file_exporter-1.0.33] startup
# [8.580s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [8.581s] [ext: omni.kit.manipulator.prim.fabric-107.0.4] startup
# [8.582s] [ext: omni.debugdraw-0.1.4] startup
# [8.584s] [ext: omni.kit.widget.stage-3.1.4] startup
# [8.590s] [ext: omni.kit.property.adapter.usd-1.0.2] startup
# [8.590s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [8.590s] [ext: omni.kvdb-107.3.26] startup
# [8.591s] [ext: omni.convexdecomposition-107.3.26] startup
# [8.593s] [ext: omni.physx.foundation-107.3.26] startup
# [8.594s] [ext: omni.localcache-107.3.26] startup
# [8.595s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [8.595s] [ext: omni.kit.widget.highlight_label-1.0.3] startup
# [8.595s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [8.595s] [ext: omni.usdphysics-107.3.26] startup
# [8.597s] [ext: omni.kit.window.file-2.0.5] startup
# [8.598s] [ext: omni.physx.cooking-107.3.26] startup
# [8.600s] [ext: omni.physics-107.3.26] startup
# [8.602s] [ext: omni.kit.window.property-1.12.1] startup
# [8.603s] [ext: omni.kit.window.content_browser-3.1.3] startup
# [8.609s] [ext: omni.physx-107.3.26] startup
# [8.615s] [ext: omni.physics.stageupdate-107.3.26] startup
# [8.616s] [ext: omni.kit.property.usd-4.5.12] startup
# [8.622s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [8.622s] [ext: omni.physics.physx-107.3.26] startup
# [8.623s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [8.624s] [ext: omni.kit.viewport.menubar.core-107.2.1] startup
# [8.631s] [ext: omni.kit.viewport.actions-107.0.2] startup
# [8.634s] [ext: omni.inspect-1.0.2] startup
# [8.634s] [ext: omni.kit.widget.layers-1.8.6] startup
# [8.640s] [ext: omni.kit.viewport.menubar.display-107.0.3] startup
# [8.641s] [ext: omni.usd.metrics.assembler-107.3.1] startup
# [8.645s] [ext: omni.graph.core-2.184.5] startup
# [8.647s] [ext: omni.kit.numpy.common-0.1.3] startup
# [8.648s] [ext: omni.usdphysics.ui-107.3.26] startup
# [8.663s] [ext: omni.physx.commands-107.3.26] startup
# [8.665s] [ext: isaacsim.core.deprecation_manager-0.2.7] startup
# [8.666s] [ext: omni.isaac.dynamic_control-2.0.7] startup
# [8.669s] [ext: omni.physx.ui-107.3.26] startup
# [8.689s] [ext: isaacsim.core.version-2.0.6] startup
# [8.689s] [ext: omni.physics.tensors-107.3.26] startup
# [8.693s] [ext: omni.warp.core-1.8.2] startup
# [8.800s] [ext: omni.usd.metrics.assembler.physics-107.3.26] startup
# [8.801s] [ext: isaacsim.storage.native-1.5.1] startup
# [8.802s] [ext: omni.physx.tensors-107.3.26] startup
# [8.805s] [ext: isaacsim.core.utils-3.5.1] startup
# [8.807s] [ext: isaacsim.core.simulation_manager-1.4.4] startup
# [8.962s] [ext: omni.kit.widget.text_editor-1.1.1] startup
# [8.963s] [ext: omni.kit.stage_templates-2.0.0] startup
# [8.964s] [ext: isaacsim.core.prims-0.6.1] startup
# [8.977s] [ext: omni.kit.window.extensions-1.4.27] startup
# [8.980s] [ext: isaacsim.core.api-4.8.0] startup
# [8.986s] [ext: omni.kit.stagerecorder.core-107.0.3] startup
# [8.988s] [ext: omni.kit.usd.collect-2.4.5] startup
# [8.989s] [ext: omni.kit.stagerecorder.ui-107.0.1] startup
# [8.990s] [ext: omni.kit.usdz_export-1.0.9] startup
# [8.991s] [ext: omni.kit.stagerecorder.bundle-105.0.2] startup
# [8.991s] [ext: omni.kit.tool.asset_importer-4.3.2] startup
# [8.994s] [ext: omni.graph.tools-1.79.2] startup
# [2026-06-04 09:11:08,804][AutoNode][DEBUG] - Defining data type 'any' as 'Any'
# [2026-06-04 09:11:08,804][AutoNode][DEBUG] - Defining data type 'bool' as 'Bool' and array 'BoolArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'bundle' as 'Bundle'
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colord[3]' as 'Color3d' and array 'Color3dArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colorf[3]' as 'Color3f' and array 'Color3fArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colorh[3]' as 'Color3h' and array 'Color3hArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colord[4]' as 'Color4d' and array 'Color4dArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colorf[4]' as 'Color4f' and array 'Color4fArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'colorh[4]' as 'Color4h' and array 'Color4hArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'double' as 'Double' and array 'DoubleArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'double[2]' as 'Double2' and array 'Double2Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'double[3]' as 'Double3' and array 'Double3Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'double[4]' as 'Double4' and array 'Double4Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'execution' as 'Execution'
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'float' as 'Float' and array 'FloatArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'float[2]' as 'Float2' and array 'Float2Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'float[3]' as 'Float3' and array 'Float3Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'float[4]' as 'Float4' and array 'Float4Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'frame[4]' as 'Frame' and array 'FrameArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'half' as 'Half' and array 'HalfArray
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'half[2]' as 'Half2' and array 'Half2Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'half[3]' as 'Half3' and array 'Half3Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'half[4]' as 'Half4' and array 'Half4Array
# [2026-06-04 09:11:08,805][AutoNode][DEBUG] - Defining data type 'int' as 'Int' and array 'IntArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'int[2]' as 'Int2' and array 'Int2Array
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'int[3]' as 'Int3' and array 'Int3Array
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'int[4]' as 'Int4' and array 'Int4Array
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'int64' as 'Int64' and array 'Int64Array
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'matrixd[2]' as 'Matrix2d' and array 'Matrix2dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'matrixd[3]' as 'Matrix3d' and array 'Matrix3dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'matrixd[4]' as 'Matrix4d' and array 'Matrix4dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'normald[3]' as 'Normal3d' and array 'Normal3dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'normalf[3]' as 'Normal3f' and array 'Normal3fArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'normalh[3]' as 'Normal3h' and array 'Normal3hArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'objectId' as 'ObjectId' and array 'ObjectIdArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'path' as 'Path'
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'pointd[3]' as 'Point3d' and array 'Point3dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'pointf[3]' as 'Point3f' and array 'Point3fArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'pointh[3]' as 'Point3h' and array 'Point3hArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'quatd[4]' as 'Quatd' and array 'QuatdArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'quatf[4]' as 'Quatf' and array 'QuatfArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'quath[4]' as 'Quath' and array 'QuathArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'string' as 'String'
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'target' as 'Target'
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'texcoordd[2]' as 'TexCoord2d' and array 'TexCoord2dArray
# [2026-06-04 09:11:08,806][AutoNode][DEBUG] - Defining data type 'texcoordf[2]' as 'TexCoord2f' and array 'TexCoord2fArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'texcoordh[2]' as 'TexCoord2h' and array 'TexCoord2hArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'texcoordd[3]' as 'TexCoord3d' and array 'TexCoord3dArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'texcoordf[3]' as 'TexCoord3f' and array 'TexCoord3fArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'texcoordh[3]' as 'TexCoord3h' and array 'TexCoord3hArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'timecode' as 'Timecode' and array 'TimecodeArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'token' as 'Token' and array 'TokenArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'uchar' as 'UChar' and array 'UCharArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'uint' as 'UInt' and array 'UIntArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'uint64' as 'UInt64' and array 'UInt64Array
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'vectord[3]' as 'Vector3d' and array 'Vector3dArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'vectorf[3]' as 'Vector3f' and array 'Vector3fArray
# [2026-06-04 09:11:08,807][AutoNode][DEBUG] - Defining data type 'vectorh[3]' as 'Vector3h' and array 'Vector3hArray
# [9.007s] [ext: omni.graph.action_core-1.1.7] startup
# [9.008s] [ext: omni.graph-1.141.2] startup
# [9.032s] [ext: omni.ui_query-1.1.8] startup
# [9.032s] [ext: omni.graph.action_nodes-1.50.4] startup
# [9.035s] [ext: omni.graph.visualization.nodes-2.1.3] startup
# [9.044s] [ext: omni.kit.ui_test-1.3.7] startup
# [9.047s] [ext: omni.graph.action-1.130.0] startup
# [9.047s] [ext: omni.kit.selection-0.1.6] startup
# [9.050s] [ext: isaacsim.gui.components-1.2.1] startup
# [9.052s] [ext: isaacsim.gui.menu-2.4.4] startup
# [9.059s] [ext: isaacsim.app.about-2.0.11] startup
# [9.062s] [ext: isaacsim.asset.importer.mjcf-2.5.13] startup
# [9.112s] [ext: semantics.schema.editor-2.0.2] startup
# [9.121s] [ext: semantics.schema.property-2.0.1] startup
# [9.122s] [ext: omni.kit.widget.graph-2.0.0] startup
# [9.126s] [ext: isaacsim.core.cloner-1.4.10] startup
# [9.127s] [ext: omni.kit.graph.delegate.default-1.2.3] startup
# [9.128s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [9.129s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [9.130s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [9.131s] [ext: omni.graph.scriptnode-1.50.0] startup
# [9.132s] [ext: omni.kit.window.material_graph-1.9.1] startup
# [9.138s] [ext: omni.graph.image.core-0.6.1] startup
# [9.139s] [ext: isaacsim.util.debug_draw-3.1.0] startup
# [9.141s] [ext: omni.kit.widget.stage_icons-1.0.8] startup
# [9.143s] [ext: omni.graph.image.nodes-1.3.1] startup
# [9.144s] [ext: omni.kit.menu.create-2.0.1] startup
# [9.146s] [ext: omni.kit.window.stage-2.6.1] startup
# [9.148s] [ext: omni.graph.nodes-1.170.10] startup
# [9.154s] [ext: omni.graph.ui_nodes-1.50.5] startup
# [9.156s] [ext: omni.syntheticdata-0.6.13] startup
# [9.172s] [ext: omni.kit.scripting-107.3.2] startup
# [9.178s] [ext: omni.videoencoding-0.1.2] startup
# [9.180s] [ext: omni.warp-1.8.2] startup
# [9.192s] [ext: isaacsim.sensors.physx-2.3.2] startup
# [9.206s] [ext: isaacsim.replicator.behavior-1.1.16] startup
# [9.210s] [ext: omni.sensors.nv.common-3.0.0] startup
# [9.227s] [ext: isaacsim.simulation_app-2.12.2] startup
# [9.230s] [ext: omni.replicator.core-1.12.27] startup
# [9.401s] [ext: omni.anim.curve.core-1.3.1] startup
# [9.413s] [ext: omni.sensors.net-1.0.0] startup
# [9.416s] [ext: omni.sensors.nv.materials-2.0.0] startup
# [9.420s] [ext: omni.kit.manipulator.camera-106.0.4] startup
# [9.425s] [ext: isaacsim.core.nodes-3.4.3] startup
# [9.437s] [ext: isaacsim.core.experimental.utils-0.3.0] startup
# [9.465s] [ext: isaacsim.test.docstring-1.1.0] startup
# [9.492s] [ext: omni.sensors.nv.ids-2.0.0] startup
# [9.496s] [ext: omni.sensors.nv.lidar-3.0.0] startup
# [9.501s] [ext: omni.kit.property.camera-1.0.10] startup
# [9.503s] [ext: omni.kit.property.audio-1.0.16] startup
# [9.505s] [ext: isaacsim.core.experimental.prims-0.8.1] startup
# [9.580s] [ext: omni.sensors.nv.wpm-3.0.0] startup
# [9.586s] [ext: omni.hydra.scene_api-0.1.2] startup
# [9.634s] [ext: omni.kit.property.light-1.0.12] startup
# [9.672s] [ext: omni.kit.property.geometry-2.0.4] startup
# [9.747s] [ext: omni.sensors.nv.radar-3.0.0] startup
# [9.762s] [ext: omni.kit.property.render-1.2.1] startup
# [9.790s] [ext: omni.kit.property.transform-1.5.13] startup
# [9.830s] [ext: omni.kit.property.material-1.11.9] startup
# [9.841s] [ext: omni.kit.widget.zoombar-1.0.6] startup
# [9.842s] [ext: isaacsim.gui.property-1.1.3] startup
# [9.844s] [ext: omni.kit.property.bundle-1.4.1] startup
# [9.845s] [ext: isaacsim.robot.surface_gripper-3.3.1] startup
# [9.848s] [ext: isaacsim.sensors.rtx-15.8.4] startup
# [9.858s] [ext: omni.kit.browser.core-2.3.13] startup
# [9.876s] [ext: omni.kit.viewport.menubar.lighting-107.3.1] startup
# [9.880s] [ext: omni.kit.viewport.menubar.camera-107.0.6] startup
# [9.887s] [ext: isaacsim.robot.manipulators-3.3.6] startup
# [9.890s] [ext: omni.kit.menu.stage-1.2.7] startup
# [9.893s] [ext: omni.kit.browser.folder.core-1.10.9] startup
# [9.924s] [ext: omni.kit.viewport.menubar.render-107.0.10] startup
# [9.939s] [ext: isaacsim.sensors.physics-0.4.3] startup
# [9.950s] [ext: omni.kit.tool.collect-2.2.18] startup
# [9.955s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [9.962s] [ext: isaacsim.robot.policy.examples-4.1.11] startup
# [9.964s] [ext: isaacsim.examples.browser-0.2.1] startup
# [9.979s] [ext: isaacsim.asset.importer.urdf-2.4.31] startup
# [9.998s] [ext: omni.rtx.window.settings-0.6.19] startup
# [10.006s] [ext: omni.ocio-0.1.1] startup
# [10.007s] [ext: omni.physx.demos-107.3.26] startup
# [10.018s] [ext: omni.kit.property.physx-107.3.26] startup
# [10.030s] [ext: omni.replicator.replicator_yaml-2.0.11] startup
# [10.033s] [ext: omni.asset_validator.core-1.1.6] startup
# [10.063s] [ext: omni.rtx.settings.core-0.6.5] startup
# [10.065s] [ext: omni.physx.vehicle-107.3.26] startup
# [10.075s] [ext: omni.kit.window.console-1.1.4] startup
# [10.078s] [ext: omni.physx.asset_validator-107.3.26] startup
# [10.081s] [ext: omni.kit.window.toolbar-2.0.0] startup
# [10.083s] [ext: omni.kit.window.script_editor-2.0.1] startup
# [10.084s] [ext: isaacsim.robot.wheeled_robots-4.0.24] startup
# [10.087s] [ext: omni.physx.camera-107.3.26] startup
# [10.094s] [ext: omni.physx.cct-107.3.26] startup
# [10.101s] [ext: omni.physx.graph-107.3.26] startup
# [10.114s] [ext: omni.physx.supportui-107.3.26] startup
# [10.129s] [ext: omni.physx.telemetry-107.3.26] startup
# [10.131s] [ext: omni.kit.window.status_bar-0.1.9] startup
# [10.135s] [ext: omni.usd.metrics.assembler.ui-107.3.1] startup
# [10.145s] [ext: isaacsim.asset.browser-1.3.23] startup
# [10.148s] [ext: isaacsim.core.throttling-2.2.2] startup
# [10.150s] [ext: omni.kit.ui.actions-1.0.5] startup
# [10.151s] [ext: omni.physx.bundle-107.3.26] startup
# [10.151s] [ext: isaacsim.sensors.camera-1.3.6] startup
# [10.155s] [ext: isaaclab-0.47.2] startup
# [10.275s] [ext: isaaclab_assets-0.2.3] startup
# [10.414s] [ext: isaaclab_tasks-0.11.6] startup
# [2026-06-04 09:11:10,232][h5py._conv][DEBUG] - Creating converter from 7 to 5
# [2026-06-04 09:11:10,233][h5py._conv][DEBUG] - Creating converter from 5 to 7
# [2026-06-04 09:11:10,233][h5py._conv][DEBUG] - Creating converter from 7 to 5
# [2026-06-04 09:11:10,233][h5py._conv][DEBUG] - Creating converter from 5 to 7
# [2026-06-04 09:11:10,279][matplotlib][DEBUG] - matplotlib data path: /home/david/miniconda3/envs/isaaclab/lib/python3.11/site-packages/matplotlib/mpl-data
# [2026-06-04 09:11:10,284][matplotlib][DEBUG] - CONFIGDIR=/home/david/.config/matplotlib
# [2026-06-04 09:11:10,290][matplotlib][DEBUG] - interactive is False
# [2026-06-04 09:11:10,290][matplotlib][DEBUG] - platform is linux
# [2026-06-04 09:11:10,418][matplotlib][DEBUG] - CACHEDIR=/home/david/.cache/matplotlib
# [2026-06-04 09:11:10,420][matplotlib.font_manager][DEBUG] - Using fontManager instance from /home/david/.cache/matplotlib/fontlist-v390.json
# [11.489s] [ext: omni.kit.menu.common-2.0.1] startup
# [11.490s] [ext: isaaclab_rl-0.4.4] startup
# [11.490s] [ext: isaaclab_mimic-1.0.15] startup
# [11.491s] [ext: isaaclab.python-2.3.0] startup
# [11.492s] Simulation App Starting
# [11.856s] app ready
# [13.546s] Simulation App Startup Complete
# [2026-06-04 09:11:13,348][filelock][DEBUG] - Attempting to release lock 124210503994512 on /tmp/isaaclab_app_launcher.lock
# [2026-06-04 09:11:13,348][filelock][DEBUG] - Lock 124210503994512 released on /tmp/isaaclab_app_launcher.lock
# 2026-06-04 09:11:14.528 | INFO     | gear_sonic.utils.motion_lib.torch_humanoid_batch:<module>:40 - Using Humanoid Batch
# [DEBUG] Instantiated events: EventCfg(physics_material=EventTermCfg(func='gear_sonic.envs.manager_env.mdp:randomize_rigid_body_material', params={'asset_cfg': SceneEntityCfg(name='robot', joint_names=None, joint_ids=slice(None, None, None), fixed_tendon_names=None, fixed_tendon_ids=slice(None, None, None), body_names='.*', body_ids=slice(None, None, None), object_collection_names=None, object_collection_ids=slice(None, None, None), preserve_order=False), 'static_friction_range': [0.3, 1.6], 'dynamic_friction_range': [0.3, 1.2], 'restitution_range': [0.0, 0.5], 'num_buckets': 64}, mode='startup', interval_range_s=None, is_global_time=False, min_step_count_between_reset=0), add_joint_default_pos=EventTermCfg(func='gear_sonic.envs.manager_env.mdp:randomize_joint_default_pos', params={'asset_cfg': SceneEntityCfg(name='robot', joint_names=['.*'], joint_ids=slice(None, None, None), fixed_tendon_names=None, fixed_tendon_ids=slice(None, None, None), body_names=None, body_ids=slice(None, None, None), object_collection_names=None, object_collection_ids=slice(None, None, None), preserve_order=False), 'pos_distribution_params': [-0.01, 0.01], 'operation': 'add'}, mode='startup', interval_range_s=None, is_global_time=False, min_step_count_between_reset=0), add_hand_joint_default_pos=None, base_com=EventTermCfg(func='gear_sonic.envs.manager_env.mdp:randomize_rigid_body_com', params={'asset_cfg': SceneEntityCfg(name='robot', joint_names=None, joint_ids=slice(None, None, None), fixed_tendon_names=None, fixed_tendon_ids=slice(None, None, None), body_names='torso_link', body_ids=slice(None, None, None), object_collection_names=None, object_collection_ids=slice(None, None, None), preserve_order=False), 'com_range': {'x': [-0.025, 0.025], 'y': [-0.05, 0.05], 'z': [-0.05, 0.05]}}, mode='startup', interval_range_s=None, is_global_time=False, min_step_count_between_reset=0), push_robot=None, randomize_rigid_body_mass=EventTermCfg(func='gear_sonic.envs.manager_env.mdp:randomize_rigid_body_mass', params={'asset_cfg': SceneEntityCfg(name='robot', joint_names=None, joint_ids=slice(None, None, None), fixed_tendon_names=None, fixed_tendon_ids=slice(None, None, None), body_names='.*wrist_yaw.*|torso_link', body_ids=slice(None, None, None), object_collection_names=None, object_collection_ids=slice(None, None, None), preserve_order=False), 'mass_distribution_params': [0.8, 1.5], 'operation': 'scale'}, mode='startup', interval_range_s=None, is_global_time=False, min_step_count_between_reset=0))
# [DEBUG]   Event 'physics_material': EventTermCfg
# [DEBUG]   Event 'add_joint_default_pos': EventTermCfg
# [DEBUG]   Event 'base_com': EventTermCfg
# [DEBUG]   Event 'randomize_rigid_body_mass': EventTermCfg
# Setting seed: 0
# [14.783s] [ext: omni.physx.fabric-107.3.26] startup
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : 0
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO] Generating terrains randomly took : 1.499654 seconds
# [2026-06-04 09:11:16,172][trimesh][DEBUG] - 2 items cleared from cache: ['face_normals', 'triangles']
# [INFO]: Time taken for scene creation : 2.086210 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 1
# 	Environment spacing   : 2.0
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : True
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# [INFO]: Time taken for simulation start : 2.420450 seconds
# 2026-06-04 09:11:19.282 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:__init__:235 - Loaded skeleton from gear_sonic/data/assets/robot_description/mjcf/g1_29dof_rev_1_0.xml
# 2026-06-04 09:11:19.282 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:__init__:236 - Loading motion data from data/demo_robot_filtered.pkl...
# 2026-06-04 09:11:19.291 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_data:472 - Loaded 1 motions
# Loading Meshes ... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00m -:--:--
# Loading Geoms... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 2026-06-04 09:11:19.587 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1091 - Loading 1 motions...
# 2026-06-04 09:11:19.587 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1092 - Sampling motion: tensor([0], device='cuda:0'), ....
# 2026-06-04 09:11:19.587 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1093 - Current motion keys: ['squat_001__A359'], ....
# 2026-06-04 09:11:19.657 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1140 - Loading motions with 1 jobs...
# Loading motions... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Gathering results for non-navigation dataset... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Processing motions... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 2026-06-04 09:11:19.691 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1577 - Loaded 1 motions with a total length of 8.460s and 424 frames.
# [INFO] Command Manager:  <CommandManager> contains 1 active terms.
# +----------------------------------+
# |       Active Command Terms       |
# +-------+--------+-----------------+
# | Index | Name   |       Type      |
# +-------+--------+-----------------+
# |   0   | motion | TrackingCommand |
# +-------+--------+-----------------+
#
# [INFO] Event Manager:  <EventManager> contains 1 active terms.
# +----------------------------------------+
# | Active Event Terms in Mode: 'startup'  |
# +--------+-------------------------------+
# | Index  | Name                          |
# +--------+-------------------------------+
# |   0    | physics_material              |
# |   1    | add_joint_default_pos         |
# |   2    | base_com                      |
# |   3    | randomize_rigid_body_mass     |
# +--------+-------------------------------+
#
# [INFO] Recorder Manager:  <RecorderManager> contains 0 active terms.
# +---------------------+
# | Active Recorder Terms |
# +-----------+---------+
# |   Index   | Name    |
# +-----------+---------+
# +-----------+---------+
#
# [INFO] Action Manager:  <ActionManager> contains 1 active terms.
# +------------------------------------+
# |  Active Action Terms (shape: 29)   |
# +--------+-------------+-------------+
# | Index  | Name        |   Dimension |
# +--------+-------------+-------------+
# |   0    | joint_pos   |          29 |
# +--------+-------------+-------------+
#
# [INFO] Observation Manager: <ObservationManager> contains 3 groups.
# +---------------------------------------------------------+
# | Active Observation Terms in Group: 'policy' (shape: (930,)) |
# +-------------+---------------------------+---------------+
# |    Index    | Name                      |     Shape     |
# +-------------+---------------------------+---------------+
# |      0      | base_ang_vel              |     (30,)     |
# |      1      | joint_pos                 |     (290,)    |
# |      2      | joint_vel                 |     (290,)    |
# |      3      | actions                   |     (290,)    |
# |      4      | gravity_dir               |     (30,)     |
# +-------------+---------------------------+---------------+
# +------------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (1645,)) |
# +-----------+-----------------------------------+------------+
# |   Index   | Name                              |   Shape    |
# +-----------+-----------------------------------+------------+
# |     0     | command_multi_future              |   (580,)   |
# |     1     | motion_anchor_pos_b               |    (3,)    |
# |     2     | motion_anchor_ori_b               |    (6,)    |
# |     3     | body_pos                          |   (42,)    |
# |     4     | body_ori                          |   (84,)    |
# |     5     | base_lin_vel                      |   (30,)    |
# |     6     | base_ang_vel                      |   (30,)    |
# |     7     | joint_pos                         |   (290,)   |
# |     8     | joint_vel                         |   (290,)   |
# |     9     | actions                           |   (290,)   |
# +-----------+-----------------------------------+------------+
# +-----------------------------------------------------------+
# |       Active Observation Terms in Group: 'tokenizer'      |
# +-------+----------------------------------------+----------+
# | Index | Name                                   |  Shape   |
# +-------+----------------------------------------+----------+
# |   0   | encoder_index                          |   (3,)   |
# |   1   | command_multi_future_nonflat           | (10, 58) |
# |   2   | command_z_multi_future_nonflat         | (10, 1)  |
# |   3   | command_z                              |   (1,)   |
# |   4   | motion_anchor_ori_b                    |   (6,)   |
# |   5   | motion_anchor_ori_b_mf_nonflat         | (10, 6)  |
# |   6   | command_multi_future_lower_body        |  (240,)  |
# |   7   | vr_3point_local_target                 |   (9,)   |
# |   8   | vr_3point_local_orn_target             |  (12,)   |
# |   9   | smpl_joints_multi_future_local_nonflat | (10, 72) |
# |   10  | smpl_root_ori_b_multi_future           | (10, 6)  |
# |   11  | joint_pos_multi_future_wrist_for_smpl  | (10, 6)  |
# +-------+----------------------------------------+----------+
#
# [INFO] Termination Manager:  <TerminationManager> contains 5 active terms.
# +------------------------------------+
# |      Active Termination Terms      |
# +-------+-----------------+----------+
# | Index | Name            | Time Out |
# +-------+-----------------+----------+
# |   0   | time_out        |   True   |
# |   1   | anchor_pos      |  False   |
# |   2   | anchor_ori_full |  False   |
# |   3   | ee_body_pos     |  False   |
# |   4   | foot_pos_xyz    |  False   |
# +-------+-----------------+----------+
#
# [INFO] Reward Manager:  <RewardManager> contains 12 active terms.
# +-----------------------------------------------+
# |              Active Reward Terms              |
# +-------+----------------------------+----------+
# | Index | Name                       |   Weight |
# +-------+----------------------------+----------+
# |   0   | tracking_anchor_pos        |      0.5 |
# |   1   | tracking_anchor_ori        |      0.5 |
# |   2   | tracking_relative_body_pos |      1.0 |
# |   3   | tracking_relative_body_ori |      1.0 |
# |   4   | tracking_body_linvel       |      1.0 |
# |   5   | tracking_body_angvel       |      1.0 |
# |   6   | action_rate_l2             |     -0.1 |
# |   7   | joint_limit                |    -10.0 |
# |   8   | undesired_contacts         |     -0.1 |
# |   9   | anti_shake_ang_vel         |   -0.005 |
# |   10  | tracking_vr_5point_local   |      2.0 |
# |   11  | feet_acc                   | -2.5e-06 |
# +-------+----------------------------+----------+
#
# [INFO] Curriculum Manager:  <CurriculumManager> contains 0 active terms.
# +----------------------+
# | Active Curriculum Terms |
# +-----------+----------+
# |   Index   | Name     |
# +-----------+----------+
# +-----------+----------+
#
# Creating window for environment.
# [INFO]: Completed setting up the environment...
# 2026-06-04 09:11:21.112 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:238 - Motion Encoder and Quantizer initialized with embedding dim: 64 (num_tokens=2, token_dim=32)
# 2026-06-04 09:11:21.127 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:307 - Initialized g1 encoder with input features: ['command_multi_future_nonflat', 'motion_anchor_ori_b_mf_nonflat']
# 2026-06-04 09:11:21.138 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:307 - Initialized teleop encoder with input features: ['command_multi_future_lower_body', 'vr_3point_local_target', 'vr_3point_local_orn_target', 'motion_anchor_ori_b']
# 2026-06-04 09:11:21.154 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:307 - Initialized smpl encoder with input features: ['smpl_joints_multi_future_local_nonflat', 'smpl_root_ori_b_multi_future', 'joint_pos_multi_future_wrist_for_smpl']
# 2026-06-04 09:11:21.186 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:397 - Initialized g1_dyn decoder with input features: ['token_flattened', 'proprioception'] and output features: ['action']
# 2026-06-04 09:11:21.198 | INFO     | gear_sonic.trl.modules.universal_token_modules:__init__:397 - Initialized g1_kin decoder with input features: ['token'] and output features: ['command_multi_future_nonflat', 'motion_anchor_ori_b_mf_nonflat']
# RunningMeanStd:  (1645,)
# [2026-06-04 09:11:21,838][datasets][DEBUG] - PyTorch version 2.7.0+cu128 available.
# /home/david/work/isaaclab-experience/dependencies/GR00T-WholeBodyControl/gear_sonic/trl/trainer/ppo_trainer.py:15: TRLExperimentalWarning: You are importing from 'trl.experimental'. APIs here are unstable and may change or be removed without notice. Silence this warning by setting environment variable TRL_EXPERIMENTAL_SILENCE=1.
#   from trl.experimental.ppo import ppo_trainer
# 2026-06-04 09:11:21.956 | INFO     | __main__:main:433 - Loading checkpoint from sonic_release/last.pt
# 2026-06-04 09:11:22.035 | INFO     | __main__:main:449 - Model parameterization: std
# 2026-06-04 09:11:22.035 | INFO     | __main__:main:450 - Checkpoint parameterization: std
# 2026-06-04 09:11:22.036 | INFO     | __main__:main:462 - Successfully loaded policy state dict
# 2026-06-04 09:11:22.045 | INFO     | gear_sonic.data.vla_token_injector:_load_tokens:58 - [vla_injector] env slot 0: (424, 64) from /home/david/work/isaaclab-experience/datasets/sonic_vla_pred_8k_final/squat_001__A359.npz (key=squat_001__A359, prompt=squat)
# 2026-06-04 09:11:22.045 | INFO     | gear_sonic.data.vla_token_injector:_install_hook:88 - [vla_injector] decode hook installed (decoder='g1_dyn', loop=True)
# 2026-06-04 09:11:22.045 | INFO     | gear_sonic.envs.wrapper.manager_env_wrapper:begin_seq_motion_samples:1016 - Loading motions for evaluation
# 2026-06-04 09:11:22.045 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1091 - Loading 1 motions...
# 2026-06-04 09:11:22.046 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1092 - Sampling motion: tensor([0], device='cuda:0'), ....
# 2026-06-04 09:11:22.046 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1093 - Current motion keys: ['squat_001__A359'], ....
# 2026-06-04 09:11:22.108 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1140 - Loading motions with 1 jobs...
# Loading motions... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Gathering results... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Processing motions... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# 2026-06-04 09:11:22.140 | INFO     | gear_sonic.utils.motion_lib.motion_lib_base:load_motions:1577 - Loaded 1 motions with a total length of 8.460s and 424 frames.
# 2026-06-04 09:11:22.551 | INFO     | __main__:main:601 - Eval step callbacks enabled: ['vla_injector']
# 2026-06-04 09:11:25.903 | INFO     | gear_sonic.envs.wrapper.manager_env_wrapper:toggle_debug_vis:1104 - Debug visualization: OFF
# ^C
#
# CondaError: KeyboardInterrupt
#
# [inject] viewer closed.

# %%
# 🚶 walk 转身走
# !bash scripts/gear_sonic_inject.sh walk

# %% [markdown]
# ### 4.7 老师 vs 学生并排对比（左 env0=GT 真 token，右 env1=GR00T 预测 token，同跳一支）
# 两机器人基本同步 = GR00T 学到位（训练集内）。机器人本体无法逐 env 上色（Isaac instanceable 资产，去实例化会破物理），用左右位置区分。

# %%
K=macarena_001__A545
GT=$PWD/datasets/sonic_vla_raw/$K/episode_000.npz
PR=$PWD/datasets/sonic_vla_pred_8k_final/$K.npz
# !cd dependencies/GR00T-WholeBodyControl && DISPLAY=:0 conda run --no-capture-output -n isaaclab \
  python gear_sonic/eval_agent_trl.py +checkpoint=sonic_release/last.pt +headless=False ++num_envs=2 \
  ++manager_env.config.terrain_type=plane ++manager_env.config.env_spacing=3.0 \
  '++manager_env.config.viewer.eye=[0.0,-7.0,3.0]' '++manager_env.config.viewer.lookat=[0.0,0.0,1.0]' \
  ++manager_env.commands.motion.use_paired_motions=True \
  ++manager_env.commands.motion.motion_lib_cfg.motion_file=data/demo_robot_filtered.pkl \
  ++manager_env.commands.motion.motion_lib_cfg.filter_motion_keys=$K \
  ++manager_env.commands.motion.motion_lib_cfg.smpl_motion_file=dummy \
  ++manager_env.terminations.anchor_pos.params.threshold=99 ++manager_env.terminations.ee_body_pos.params.threshold=99 \
  ++manager_env.terminations.anchor_ori_full.params.threshold=99 ++manager_env.terminations.foot_pos_xyz.params.threshold=99 \
  '++eval_callbacks=[vla_injector]' \
  ++callbacks.vla_injector._target_=gear_sonic.data.vla_token_injector.VlaTokenInjector \
  "++callbacks.vla_injector.token_npz='$GT,$PR'"

# %% [markdown]
# ## 路线图：已完成 vs 下一步
#
# **✅ 已跑通（见 ④）**：record → convert → finetune GR00T-N1.7（DiT 头出 64 维 SONIC token）→ open-loop MSE **0.0011**（破基线 35×）→ 注入 SONIC 解码 → 踢腿/舞步与 GT 基本同步。架构侧 GO（**训练集内**）。
#
# **⏭️ 真正的下一步**：
# 1. **泛化（held-out）**：新 episode / 改写 prompt / 新起始姿态测 MSE —— 现在是 7-ep **过拟合**，没测过泛化。
# 2. **实时 prompt 活循环**：现演示是**开环回放**（离线 dump token 再注入）；要"敲 prompt → 机器人当场反应"，需 GR00T 在环 live `get_action`（in-process 或官方 `run_vla_inference.py` ZMQ）。
# 3. **数据多样性**：DR 放量近乎复制（实测 95% 重复）→ 真多样性靠**更多编舞 clip + RSI 相位**（Bones-SEED G1 CSV / LAFAN）。
# 4. **闭环纠偏**：开环长动作（如 macarena 27.5s）位置会漂；活循环里 GR00T 按实时 obs 出 token 可自纠。
#
# > 数据侧便宜替代（DART/DAgger 治 raw-joint ACT covariate shift）见 `doc/vla_data_expansion_covariate_shift.html`。架构侧天花板高、架设重；数据侧便宜快。
